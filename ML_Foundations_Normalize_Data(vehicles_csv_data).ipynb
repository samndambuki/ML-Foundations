# %% [markdown]
# <a href="https://colab.research.google.com/github/samndambuki/ML-Foundations/blob/main/ML_Foundations_Normalize_Data(vehicles_csv_data).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Normalize Data
import pandas as pd 
vehicles = pd.read_csv('/content/drive/MyDrive/vehicles.csv')
vehicles.head()
# Out:
#    citympg  cylinders  displacement             drive  highwaympg      make  \
# 0     14.0          6           4.1     2-Wheel Drive        19.0     Buick
# 1     14.0          8           5.0     2-Wheel Drive        20.0     Buick
# 2     18.0          8           5.7     2-Wheel Drive        26.0     Buick
# 3     21.0          6           4.3  Rear-Wheel Drive        31.0  Cadillac
# 4     14.0          8           4.1  Rear-Wheel Drive        19.0  Cadillac
#
#                      model       class  year transmissiontype  \
# 0      Electra/Park Avenue  Large Cars  1984        Automatic
# 1      Electra/Park Avenue  Large Cars  1984        Automatic
# 2      Electra/Park Avenue  Large Cars  1984        Automatic
# 3  Fleetwood/DeVille (FWD)  Large Cars  1984        Automatic
# 4   Brougham/DeVille (RWD)  Large Cars  1984        Automatic
#
#    transmissionspeeds  co2emissions
# 0                   4    555.437500
# 1                   4    555.437500
# ...

# %%
vehicles[['co2emissions']].describe()
# Out:
#        co2emissions
# count  36979.000000
# mean     476.550703
# std      117.791357
# min       29.000000
# 25%      400.000000
# 50%      467.736842
# 75%      555.437500
# max     1269.571429

# %%
vehicles[['co2emissions']].plot(kind='hist',
                                bins=20,
                                figsize=(10,6))

# %%
#Min-max normalization
from sklearn.preprocessing import MinMaxScaler

# %%
co2emissions_mm = MinMaxScaler().fit_transform(vehicles[['co2emissions']])
co2emissions_mm
# Out:
# array([[0.42435082],
#        [0.42435082],
#        [0.36738062],
#        ...,
#        [0.38208199],
#        [0.50944265],
#        [0.41674344]])

# %%
co2emissions_mm = pd.DataFrame(co2emissions_mm,columns=['co2emissions'])
co2emissions_mm
# Out:
#        co2emissions
# 0          0.424351
# 1          0.424351
# 2          0.367381
# 3          0.318536
# 4          0.424351
# ...             ...
# 36974      0.332911
# 36975      0.352257
# 36976      0.382082
# 36977      0.509443
# 36978      0.416743
#
# [36979 rows x 1 columns]

# %%
#z-score normalization
from sklearn.preprocessing import StandardScaler
co2emissions_zm = StandardScaler().fit_transform(vehicles[['co2emissions']])
co2emissions_zm = pd.DataFrame(co2emissions_zm,columns=['c02emissions'])
co2emissions_zm.describe()
# Out:
#        c02emissions
# count  3.697900e+04
# mean  -1.844617e-16
# std    1.000014e+00
# min   -3.799572e+00
# 25%   -6.498927e-01
# 50%   -7.482706e-02
# 75%    6.697254e-01
# max    6.732510e+00

# %%
co2emissions_zm.plot(kind='hist',
                    bins=20,
                    figsize=(10,6))
